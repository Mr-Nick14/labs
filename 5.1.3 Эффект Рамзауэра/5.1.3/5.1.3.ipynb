# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('2.65.csv', delimiter=',', names=True)

x = data['v1']
y = data['v2']

# Построение точек на графике
plt.scatter(x, y, label='R(Q), T = 296.2 K', s=10, c=(0,0,0))

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')

plt.xlabel('Q')
plt.ylabel('R')
plt.legend()
plt.show()
# Out:
# k: 2.210023647535874
# b: 22.598484096794156
# Стандартная ошибка наклона k: 1.106142113450421
# В процентах:  50.0511437822733
# Стандартная ошибка смещения b: 7.033258319404882
# В процентах:  31.122699599140937
# /var/folders/tk/kzjtwq4j7ml5s_9f1mx01cwr0000gn/T/ipykernel_30062/4095276778.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='R(Q), T = 296.2 K', s=10, c=(0,0,0))
