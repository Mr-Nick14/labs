# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('t1.csv', delimiter=',', names=True)

x = data['Q']
y = data['R']

# Построение точек на графике
plt.scatter(x, y, label='R(Q), T = 296.2 K', s=10, c=(0,0,0))

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')

plt.xlabel('Q')
plt.ylabel('R')
plt.legend()
plt.show()
# Out:
# k: 0.005258255913944325
# b: 20.278448600105925
# Стандартная ошибка наклона k: 2.2963643512129926e-05
# В процентах:  0.43671597366025555
# Стандартная ошибка смещения b: 0.0042454789027677915
# В процентах:  0.020935915693006294
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_16938/868131863.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='R(Q), T = 296.2 K', s=10, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('t2.csv', delimiter=',', names=True)

x = data['Q']
y = data['R']

# Построение точек на графике
plt.scatter(x, y, label='R(Q), T = 306.4 К', s=10, c=(0,0,0))

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')

plt.xlabel('Q')
plt.ylabel('R')
plt.legend()
plt.show()
# Out:
# k: 0.005141866955756109
# b: 20.98117471071836
# Стандартная ошибка наклона k: 1.940737559975011e-05
# В процентах:  0.37743830726744787
# Стандартная ошибка смещения b: 0.0036454279394533824
# В процентах:  0.01737475613122412
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_16938/3564012392.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='R(Q), T = 306.4 К', s=10, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('t3.csv', delimiter=',', names=True)

x = data['Q']
y = data['R']

# Построение точек на графике
plt.scatter(x, y, label='R(Q), T = 316.4 K', s=10, c=(0,0,0))

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')

plt.xlabel('Q')
plt.ylabel('R')
plt.legend()
plt.show()
# Out:
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_16938/2529294390.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='R(Q), T = 316.4 K', s=10, c=(0,0,0))
# k: 0.005000114648228732
# b: 21.691706201409335
# Стандартная ошибка наклона k: 1.7225385030965436e-05
# В процентах:  0.3444998013609038
# Стандартная ошибка смещения b: 0.0031963052486733384
# В процентах:  0.014735149088759421

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('t4.csv', delimiter=',', names=True)

x = data['Q']
y = data['R']

# Построение точек на графике
plt.scatter(x, y, label='$R(Q)$, $T = 326.4$ K', s=10, c=(0,0,0))

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')

plt.xlabel('$Q$')
plt.ylabel('$R$')
plt.legend()
plt.show()
# Out:
# k: 0.004863633179235159
# b: 22.394346828171916
# Стандартная ошибка наклона k: 1.214393139131378e-05
# В процентах:  0.24968847246048892
# Стандартная ошибка смещения b: 0.002225690077336413
# В процентах:  0.009938624664580582
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_15871/2433812831.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$R(Q)$, $T = 326.4$ K', s=10, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('t5.csv', delimiter=',', names=True)

x = data['Q']
y = data['R']

# Построение точек на графике
plt.scatter(x, y, label='$R(Q)$, $T = 336.3$ K', s=10, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')


plt.xlabel('$Q$')
plt.ylabel('$R$')
plt.legend()
plt.show()
# Out:
# k: 0.004744989745522941
# b: 23.094349899338326
# Стандартная ошибка наклона k: 1.0776918878717657e-05
# В процентах:  0.2271220688914248
# Стандартная ошибка смещения b: 0.0019505268072421069
# В процентах:  0.008445904802446901
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_15871/785671590.py:13: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$R(Q)$, $T = 336.3$ K', s=10, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('R0(T).csv', delimiter=',', names=True)

x = data['T']
y = data['R']

# Построение точек на графике
plt.scatter(x, y, label='$R(T)$', s=10, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')


plt.xlabel('$T$')
plt.ylabel('$R$')
plt.legend()
plt.show()
# Out:
# k: 0.07035851446965834
# b: 18.64873368577894
# Стандартная ошибка наклона k: 9.948556002145271e-05
# В процентах:  0.14139803941476795
# Стандартная ошибка смещения b: 0.004473206131461786
# В процентах:  0.023986648138328782
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_15871/2039279861.py:13: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$R(T)$', s=10, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('kappa(T).csv', delimiter=',', names=True)
data_real = np.genfromtxt('kappa(T)_real.csv', delimiter=',', names=True)
x = data['T']
y = data['kappa']

x_real = data_real['T']
y_real = data_real['kappa']
# Построение точек на графике
plt.scatter(x, y, label='$\kappa (T)$', s=10, c='red')
plt.scatter(x_real, y_real, label='$\kappa_{real} (T)$', s=10, c='blue')

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

coefficients_real = np.polyfit(x_real, y_real, 1)
polynomial_real = np.poly1d(coefficients_real)
y_fit_real = polynomial_real(x_real)

# Создаем и обучаем модель линейной регрессии
new_x_real = x_real.reshape(-1, 1)
model_real = LinearRegression()
model_real.fit(new_x_real, y_real)

new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")
print()
a_real = model_real.coef_[0]
b_real = model_real.intercept_
print(f"k_real: {a_real}")
print(f"b_real: {b_real}")
# Предсказываем значения
y_pred = model.predict(new_x)

y_pred_real = model_real.predict(new_x_real)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

mse_real = mean_squared_error(y_real, y_pred_real)

# Количество наблюдений
n = len(x)

n_real = len(x_real)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

se_a_real = np.sqrt(mse_real / ((n_real - 1) * np.var(x_real)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

se_b_real = np.sqrt(mse_real * (1/n_real + np.mean(x_real)**2 / ((n_real - 1) * np.var(x_real))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)
print()
print("Стандартная ошибка наклона k_real:", se_a_real)
print("В процентах: ", se_a_real / a_real * 100)
print("Стандартная ошибка смещения b_real:", se_b_real)
print("В процентах: ", se_b_real / b_real * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='red')
plt.plot(x_real, y_fit_real, color='blue')


plt.xlabel('$T$')
plt.ylabel('$\kappa$')
plt.legend()
plt.show()
# Out:
# k: 0.07293851191993879
# b: 24.555432595773844
#
# k_real: 0.07800000000000006
# b_real: 24.38
# Стандартная ошибка наклона k: 0.0017431384435627288
# В процентах:  2.389873878255277
# Стандартная ошибка смещения b: 0.07837738031579804
# В процентах:  0.31918550003182317
#
# Стандартная ошибка наклона k_real: 0.0020000000000000464
# В процентах:  2.564102564102622
# Стандартная ошибка смещения b_real: 0.08390470785361406
# В процентах:  0.34415384681548017
# <>:15: SyntaxWarning: invalid escape sequence '\k'
# <>:16: SyntaxWarning: invalid escape sequence '\k'
# <>:87: SyntaxWarning: invalid escape sequence '\k'
# <>:15: SyntaxWarning: invalid escape sequence '\k'
# <>:16: SyntaxWarning: invalid escape sequence '\k'
# <>:87: SyntaxWarning: invalid escape sequence '\k'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_15871/2339634683.py:15: SyntaxWarning: invalid escape sequence '\k'
#   plt.scatter(x, y, label='$\kappa (T)$', s=10, c='red')
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_15871/2339634683.py:16: SyntaxWarning: invalid escape sequence '\k'
#   plt.scatter(x_real, y_real, label='$\kappa_{real} (T)$', s=10, c='blue')
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_15871/2339634683.py:87: SyntaxWarning: invalid escape sequence '\k'
#   plt.ylabel('$\kappa$')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('ln(kappa)(ln(T)).csv', delimiter=',', names=True)

x = data['lnT']
y = data['lnKappa']

# Построение точек на графике
plt.scatter(x, y, label='$\ln \kappa$ от $\ln T$', s=10, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')


plt.xlabel('T')
plt.ylabel('R')
plt.legend()
plt.show()
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\l'
# <>:13: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_46714/2297820369.py:13: SyntaxWarning: invalid escape sequence '\l'
#   plt.scatter(x, y, label='$\ln \kappa$ от $\ln T$', s=10, c=(0,0,0))
# k: 0.8383060826669844
# b: -1.5041221506146294
# Стандартная ошибка наклона k: 0.01989426664861777
# В процентах:  2.3731506975741143
# Стандартная ошибка смещения b: 0.11451020020397393
# В процентах:  -7.613091806219437
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_46714/2297820369.py:13: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$\ln \kappa$ от $\ln T$', s=10, c=(0,0,0))
