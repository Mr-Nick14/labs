# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('5.1.1.csv', delimiter=',', names=True)

x = data['x']
y = data['y']

# Построение точек на графике
plt.scatter(x, y, label='R(Q), T = 296.2 K', s=10, c=(0,0,0))

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')

plt.xlabel('Q')
plt.ylabel('R')
plt.legend()
plt.show()
# Out:
# k: 3.0532115353105045
# b: -21.260771669670664
# Стандартная ошибка наклона k: 0.11924106594548742
# В процентах:  3.905430873899829
# Стандартная ошибка смещения b: 0.8569924146632418
# В процентах:  -4.030862228231234
# /var/folders/v8/9mcs8vfj23v2v616rb2ng7mc0000gn/T/ipykernel_77915/1619527494.py:14: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='R(Q), T = 296.2 K', s=10, c=(0,0,0))
