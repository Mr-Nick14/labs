# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('40.9.csv', delimiter=',', names=True)

x = data['t']
y = data['U']

y = np.log(y)



# Построение точек на графике
plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 40.9 торр', s=0.5, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')
plt.annotate('', xy=(0.95, 0), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))
plt.annotate('', xy=(0, 0.95), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))


plt.xlabel('$t$')
plt.ylabel('$U$')
plt.legend()
plt.show()
# Out:
# k: -0.0021422518823920847
# b: 2.20630284226186
# Стандартная ошибка наклона k: 8.365757542182576e-07
# В процентах:  -0.039051232074732455
# Стандартная ошибка смещения b: 0.00011503403244747057
# В процентах:  0.0052138822578653736
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2064917278.py:17: SyntaxWarning: invalid escape sequence '\l'
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 40.9 торр', s=0.5, c=(0,0,0))
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2064917278.py:17: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 40.9 торр', s=0.5, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('74.4.csv', delimiter=',', names=True)

x = data['t']
y = data['U']

y = np.log(y)



# Построение точек на графике
plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 74.4 торр', s=0.5, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')
plt.annotate('', xy=(0.95, 0), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))
plt.annotate('', xy=(0, 0.95), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))


plt.xlabel('$t$')
plt.ylabel('$U$')
plt.legend()
plt.show()
# Out:
# k: -0.0012184089680956458
# b: 2.381872908892975
# Стандартная ошибка наклона k: 6.559710224708337e-07
# В процентах:  -0.053838328479813
# Стандартная ошибка смещения b: 0.00016212209166394705
# В процентах:  0.006806496310472613
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2565022862.py:17: SyntaxWarning: invalid escape sequence '\l'
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 74.4 торр', s=0.5, c=(0,0,0))
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2565022862.py:17: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 74.4 торр', s=0.5, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('104.1.csv', delimiter=',', names=True)

x = data['t']
y = data['U']

y = np.log(y)



# Построение точек на графике
plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 104.1 торр', s=0.5, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')
plt.annotate('', xy=(0.95, 0), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))
plt.annotate('', xy=(0, 0.95), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))


plt.xlabel('$t$')
plt.ylabel('$U$')
plt.legend()
plt.show()
# Out:
# k: -0.0008137820554359451
# b: 2.587846349533095
# Стандартная ошибка наклона k: 7.639016647762259e-07
# В процентах:  -0.09387054674817102
# Стандартная ошибка смещения b: 0.00031716182909259866
# В процентах:  0.012255821492254427
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2227493848.py:17: SyntaxWarning: invalid escape sequence '\l'
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 104.1 торр', s=0.5, c=(0,0,0))
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2227493848.py:17: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 104.1 торр', s=0.5, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('148.7.csv', delimiter=',', names=True)

x = data['t']
y = data['U']

y = np.log(y)



# Построение точек на графике
plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 148.7 торр', s=0.5, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')
plt.annotate('', xy=(0.95, 0), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))
plt.annotate('', xy=(0, 0.95), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))


plt.xlabel('$t$')
plt.ylabel('$U$')
plt.legend()
plt.show()
# Out:
# k: -0.0006051364664774622
# b: 2.4933537936628323
# Стандартная ошибка наклона k: 6.603950464668983e-07
# В процентах:  -0.10913158982321788
# Стандартная ошибка смещения b: 0.0003180343829777366
# В процентах:  0.012755285021566552
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2740964917.py:17: SyntaxWarning: invalid escape sequence '\l'
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 148.7 торр', s=0.5, c=(0,0,0))
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/2740964917.py:17: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 148.7 торр', s=0.5, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('185.9.csv', delimiter=',', names=True)

x = data['t']
y = data['U']

y = np.log(y)



# Построение точек на графике
plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 185.9 торр', s=0.5, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')
plt.annotate('', xy=(0.95, 0), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))
plt.annotate('', xy=(0, 0.95), xytext=(0, 0),
             arrowprops=dict(arrowstyle="->"))


plt.xlabel('$t$')
plt.ylabel('$U$')
plt.legend()
plt.show()
# Out:
# k: -0.00047910945786620775
# b: 2.5031715380122823
# Стандартная ошибка наклона k: 4.191998259834002e-07
# В процентах:  -0.08749562737717079
# Стандартная ошибка смещения b: 0.00025947620775756573
# В процентах:  0.010365897974519577
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# <>:17: SyntaxWarning: invalid escape sequence '\l'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/437827257.py:17: SyntaxWarning: invalid escape sequence '\l'
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 185.9 торр', s=0.5, c=(0,0,0))
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/437827257.py:17: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 185.9 торр', s=0.5, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('D(1\P).csv', delimiter=',', names=True)

x = data['P']
y = data['D']
errors_y = data['deltaD']

xAtm = [1.32]
yAtm = [0.61]

# Построение точек на графике
plt.scatter(x, y, label='$D(\\frac{1}{P})$', s=2, c=(0,0,0))
plt.scatter(xAtm, yAtm, label='$точка\;P = 758.5\;торр$', s=8, c='red')

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')


plt.xlabel('$\\frac{1}{P},\;торр^{-1} \cdot 10^{-3}$')
plt.ylabel('$D,\;см^2/c$')
plt.legend()
plt.show()
# Out:
# k: 0.5437374134985709
# b: -0.10815052398075675
# Стандартная ошибка наклона k: 0.01513216161089713
# В процентах:  2.7829906927927266
# Стандартная ошибка смещения b: 0.12335757878834504
# В процентах:  -114.06100890486124
# <>:7: SyntaxWarning: invalid escape sequence '\P'
# <>:18: SyntaxWarning: invalid escape sequence '\;'
# <>:60: SyntaxWarning: invalid escape sequence '\;'
# <>:61: SyntaxWarning: invalid escape sequence '\;'
# <>:7: SyntaxWarning: invalid escape sequence '\P'
# <>:18: SyntaxWarning: invalid escape sequence '\;'
# <>:60: SyntaxWarning: invalid escape sequence '\;'
# <>:61: SyntaxWarning: invalid escape sequence '\;'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/765531752.py:7: SyntaxWarning: invalid escape sequence '\P'
#   data = np.genfromtxt('D(1\P).csv', delimiter=',', names=True)
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/765531752.py:18: SyntaxWarning: invalid escape sequence '\;'
#   plt.scatter(xAtm, yAtm, label='$точка\;P = 758.5\;торр$', s=8, c='red')
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/765531752.py:60: SyntaxWarning: invalid escape sequence '\;'
#   plt.xlabel('$\\frac{1}{P},\;торр^{-1} \cdot 10^{-3}$')
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/765531752.py:61: SyntaxWarning: invalid escape sequence '\;'
#   plt.ylabel('$D,\;см^2/c$')
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_19836/765531752.py:17: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$D(\\frac{1}{P})$', s=2, c=(0,0,0))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Загрузка данных из CSV файла
data = np.genfromtxt('77.7.csv', delimiter=',', names=True)

x = data['t']
y = data['U']

y = np.log(y)




# Построение точек на графике
plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 40.9 торр, 7 пункт измерений', s=0.5, c=(0,0,0))

# МНК для построения сглаживающей прямой
coefficients = np.polyfit(x, y, 1)
polynomial = np.poly1d(coefficients)
y_fit = polynomial(x)

# Создаем и обучаем модель линейной регрессии
new_x = x.reshape(-1, 1)
model = LinearRegression()
model.fit(new_x, y)

# Получаем коэффициенты зависимости
a = model.coef_[0]
b = model.intercept_
print(f"k: {a}")
print(f"b: {b}")

# Предсказываем значения
y_pred = model.predict(new_x)

# Среднеквадратичная ошибка модели
mse = mean_squared_error(y, y_pred)

# Количество наблюдений
n = len(x)

# Стандартная ошибка наклона a
se_a = np.sqrt(mse / ((n - 1) * np.var(x)))

# Стандартная ошибка смещения b
se_b = np.sqrt(mse * (1/n + np.mean(x)**2 / ((n - 1) * np.var(x))))

print("Стандартная ошибка наклона k:", se_a)
print("В процентах: ", se_a / a * 100)
print("Стандартная ошибка смещения b:", se_b)
print("В процентах: ", se_b / b * 100)

# Построение сглаживающей прямой
plt.plot(x, y_fit, color='pink')



plt.xlabel('$t,\;с$')
plt.ylabel('$U,\;мВ$')
plt.legend()
plt.show()
# Out:
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# <>:61: SyntaxWarning: invalid escape sequence '\;'
# <>:62: SyntaxWarning: invalid escape sequence '\;'
# <>:18: SyntaxWarning: invalid escape sequence '\l'
# <>:61: SyntaxWarning: invalid escape sequence '\;'
# <>:62: SyntaxWarning: invalid escape sequence '\;'
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_23976/753782022.py:18: SyntaxWarning: invalid escape sequence '\l'
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 40.9 торр, 7 пункт измерений', s=0.5, c=(0,0,0))
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_23976/753782022.py:61: SyntaxWarning: invalid escape sequence '\;'
#   plt.xlabel('$t,\;с$')
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_23976/753782022.py:62: SyntaxWarning: invalid escape sequence '\;'
#   plt.ylabel('$U,\;мВ$')
# /var/folders/sg/74hjk3n536n5j54_g0zlgs080000gn/T/ipykernel_23976/753782022.py:18: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x, y, label='$ln \left( \\frac{U}{U_0} \\right) = - \\frac{t}{\\tau}$, 40.9 торр, 7 пункт измерений', s=0.5, c=(0,0,0))
# k: -0.0012824136008277066
# b: 2.309393592493987
# Стандартная ошибка наклона k: 6.569248612893607e-06
# В процентах:  -0.5122566236550848
# Стандартная ошибка смещения b: 0.0014451644445111122
# В процентах:  0.06257765888015797
